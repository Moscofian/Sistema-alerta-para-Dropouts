# %% [markdown]
# Dataset:
# https://www.kaggle.com/datasets/abdullah0a/student-dropout-analysis-and-prediction-dataset
#
# Licença: MIT
# CC0: Public Domain
#
# ### Descrição das Colunas:
#
# 1. **School (Escola):** Nome da escola frequentada (ex: MS).
# 2. **Gender (Gênero):** Gênero do estudante (ex: M para Masculino, F para Feminino).
# 3. **Age (Idade):** Idade do estudante.
# 4. **Address (Endereço):** Tipo de residência (U para urbana, R para rural).
# 5. **Family_Size (Tamanho_da_Família):** Tamanho da família (GT3 para maior que 3 pessoas, LE3 para menor ou igual a 3 pessoas).
# 6. **Parental_Status (Estado_dos_Pais):** Situação de coabitação dos pais (A para morando juntos, T para morando separados).
# 7. **Mother_Education (Escolaridade_da_Mãe):** Nível de escolaridade da mãe (0 a 4).
# 8. **Father_Education (Escolaridade_do_Pai):** Nível de escolaridade do pai (0 a 4).
# 9. **Mother_Job (Profissão_da_Mãe):** Tipo de trabalho exercido pela mãe.
# 10. **Father_Job (Profissão_do_Pai):** Tipo de trabalho exercido pelo pai.
# 11. **Reason_for_Choosing_School (Motivo_da_Escolha):** Razão pela qual escolheu a escola (ex: curso).
# 12. **Guardian (Responsável):** Responsável legal pelo estudante (ex: mãe).
# 13. **Travel_Time (Tempo_de_Viagem):** Tempo de deslocamento até a escola (em minutos).
# 14. **Study_Time (Tempo_de_Estudo):** Horas de estudo semanais (escala de 1 a 4).
# 15. **Number_of_Failures (Número_de_Reprovações):** Quantidade de reprovações em turmas anteriores.
# 16. **School_Support (Apoio_Escolar):** Se o estudante recebe apoio educacional extra da escola (sim/não).
# 17. **Family_Support (Apoio_Familiar):** Se a família oferece apoio educacional em casa (sim/não).
# 18. **Extra_Paid_Class (Aulas_Particulares):** Participação em aulas extras pagas/reforço (sim/não).
# 19. **Extra_Curricular_Activities (Atividades_Extracurriculares):** Envolvimento em atividades extracurriculares (sim/não).
# 20. **Attended_Nursery (Frequentou_Creche):** Se frequentou a creche/educação infantil quando criança (sim/não).
# 21. **Wants_Higher_Education (Deseja_Ensino_Superior):** Desejo de cursar o ensino superior/faculdade (sim/não).
# 22. **Internet_Access (Acesso_à_Internet):** Disponibilidade de internet em casa (sim/não).
# 23. **In_Relationship (Namorando):** Status de relacionamento amoroso (sim/não).
# 24. **Family_Relationship (Relacionamento_Familiar):** Qualidade das relações familiares (escala de 1 a 5).
# 25. **Free_Time (Tempo_Livre):** Quantidade de tempo livre após a escola (escala de 1 a 5).
# 26. **Going_Out (Sair_com_Amigos):** Frequência de saídas com amigos (escala de 1 a 5).
# 27. **Weekend_Alcohol_Consumption (Consumo_Álcool_Fim_de_Semana):** Consumo de álcool nos fins de semana (escala de 1 a 5).
# 28. **Weekday_Alcohol_Consumption (Consumo_Álcool_Dias_Úteis):** Consumo de álcool em dias úteis (escala de 1 a 5).
# 29. **Health_Status (Estado_de_Saúde):** Avaliação do estado de saúde do estudante (escala de 1 a 5).
# 30. **Number_of_Absences (Número_de_Faltas):** Quantidade total de faltas na escola.
# 31. **Grade_1 (Nota_1):** Nota recebida na primeira avaliação (geralmente primeiro bimestre/trimestre).
# 32. **Grade_2 (Nota_2):** Nota recebida na segunda avaliação.
# 33. **Final_Grade (Nota_Final):** Nota final recebida no fim do ano (G3).
# 34. **Dropped_Out (Evadiu):** Indicador se o aluno abandonou a escola ou não (True para Sim / False para Não).

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.14.5

# %%
# Imports
# Manipulação de dados
import pandas as pd
# Trabalho com vetores, matrizes e matemática
import numpy as np
# Pacote para gráficos
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Carregando e Compreendendo os Dados

# %%
# Carrega o dataset
df = pd.read_csv('./student dropout.csv')

# %%
# Tamanho do dataset em linhas e colunas
print("Linhas: {} \nColunas: {}".format(*df.shape))
# Out:
# Linhas: 649
# Colunas: 34

# %%
# Mostra as 5 primeiras linhas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df.head()
# Out:
#   School Gender  Age Address Family_Size Parental_Status  Mother_Education  \
# 0     GP      F   18       U         GT3               A                 4
# 1     GP      F   17       U         GT3               T                 1
# 2     GP      F   15       U         LE3               T                 1
# 3     GP      F   15       U         GT3               T                 4
# 4     GP      F   16       U         GT3               T                 3
#
#    Father_Education Mother_Job Father_Job Reason_for_Choosing_School Guardian  \
# 0                 4    at_home    teacher                     course   mother
# 1                 1    at_home      other                     course   father
# 2                 1    at_home      other                      other   mother
# 3                 2     health   services                       home   mother
# 4                 3      other      other                       home   father
#
# ...

# %%
# Mostra 10 linhas aleatórias 
df.sample(10)
# Out:
#     School Gender  Age Address Family_Size Parental_Status  Mother_Education  \
# 106     GP      F   15       U         GT3               T                 2
# 530     MS      M   17       U         GT3               T                 3
# 15      GP      F   16       U         GT3               T                 4
# 528     MS      F   17       R         GT3               T                 2
# 612     MS      M   17       R         GT3               T                 4
# 271     GP      F   17       U         GT3               T                 4
# 421     GP      F   20       U         GT3               T                 1
# 646     MS      F   18       U         GT3               T                 1
# 45      GP      F   15       U         LE3               A                 4
# 65      GP      F   16       U         LE3               T                 4
#
#      Father_Education Mother_Job Father_Job Reason_for_Choosing_School  \
# ...

# %% [markdown]
# ## Análise Exploratória de Dados (EDA)

# %%
# Informações do dataset
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   School                       649 non-null    str
#  1   Gender                       649 non-null    str
#  2   Age                          649 non-null    int64
#  3   Address                      649 non-null    str
#  4   Family_Size                  649 non-null    str
#  5   Parental_Status              649 non-null    str
#  6   Mother_Education             649 non-null    int64
#  7   Father_Education             649 non-null    int64
#  8   Mother_Job                   649 non-null    str
#  9   Father_Job                   649 non-null    str
#  10  Reason_for_Choosing_School   649 non-null    str
#  11  Guardian                     649 non-null    str
#  12  Travel_Time                  649 non-null    int64
# ...

# %%
# Não tem valores null
df.isnull().sum()
# Out:
# School                         0
# Gender                         0
# Age                            0
# Address                        0
# Family_Size                    0
# Parental_Status                0
# Mother_Education               0
# Father_Education               0
# Mother_Job                     0
# Father_Job                     0
# Reason_for_Choosing_School     0
# Guardian                       0
# Travel_Time                    0
# Study_Time                     0
# Number_of_Failures             0
# School_Support                 0
# Family_Support                 0
# Extra_Paid_Class               0
# Extra_Curricular_Activities    0
# Attended_Nursery               0
# Wants_Higher_Education         0
# Internet_Access                0
# In_Relationship                0
# Family_Relationship            0
# Free_Time                      0
# Going_Out                      0
# Weekend_Alcohol_Consumption    0
# Weekday_Alcohol_Consumption    0
# ...

# %%
# Relação entre alunos
print("\nDistribuição das evasões:\n")
situacao = df['Dropped_Out'].map({False: 'Não Evasão', True: 'Evasão'})
ax = sns.countplot(x=situacao, order=['Não Evasão', 'Evasão'])
ax.bar_label(ax.containers[0])
plt.title('Distribuição dos alunos')
plt.xlabel('Situação')
plt.ylabel('Quantidade')
plt.show()
# Out:
# Distribuição das evasões:

# %%
# Relação entre nota final e frequência
plt.figure(figsize=(10, 6))
sns.histplot(df['Final_Grade'], bins=20, kde=True)
plt.title('Distribuição da Nota Final')
plt.xlabel('Nota Final (G3)')
plt.ylabel('Frequência')
plt.show()

# %%
# Taxa de evasão por gênero
situacao = df['Dropped_Out'].map({False: 'Não Evasão', True: 'Evasão'})

fig, ax = plt.subplots(figsize=(8, 5))
sns.countplot(data=df, x='Gender', hue=situacao, hue_order=['Não Evasão', 'Evasão'], ax=ax)

ax.set_title('Taxa de evasão por gênero')
ax.set_xlabel('Gênero')
ax.set_ylabel('Quantidade')

for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', 
                xytext = (0, 5), 
                textcoords = 'offset points')

ax.legend(title='Situação')

plt.show()

# %%
# Evasão por idade
situacao = df['Dropped_Out'].map({False: 'Não Evasão', True: 'Evasão'})
ax = sns.countplot(data=df, x='Age', hue=situacao, hue_order=['Não Evasão', 'Evasão'])
ax.legend(title='Situação')
plt.title('Evasão por idade')
plt.xlabel('Idade')
plt.ylabel('Quantidade')
plt.show()

# %%
# Taxa de evasão por faixa de faltas
# Um boxplot aqui é pouco informativo: a distribuição de faltas é muito
# assimétrica e ~35% dos alunos têm zero faltas nos dois grupos.
# Este gráfico responde a pergunta de forma direta:
# quanto mais faltas, maior a chance de evasão?
faixas = pd.cut(
    df['Number_of_Absences'],
    bins=[-1, 0, 5, 10, 20, df['Number_of_Absences'].max()],
    labels=['0', '1-5', '6-10', '11-20', '21+']
)
taxa_evasao = df.groupby(faixas, observed=True)['Dropped_Out'].mean() * 100

ax = taxa_evasao.plot(kind='bar', color=sns.color_palette()[0], rot=0)
ax.bar_label(ax.containers[0], fmt='%.1f%%')
plt.title('Taxa de evasão por faixa de faltas')
plt.xlabel('Faixa de faltas')
plt.ylabel('Taxa de evasão (%)')
plt.ylim(0, 45)
plt.show()
# Obs: a faixa 21+ tem poucos alunos (8), então a taxa dela é menos confiável

# %%
# Heatmap
# Número positivo = diretamente proporcional
# Número negativo = inversamente proporcional
plt.figure(figsize=(12, 8))
sns.heatmap(
    df.corr(numeric_only=True), 
    annot=True, 
    cmap='PuOr', 
    fmt='.2f',
    vmin=-1,
    vmax=1,
    center=0,
    linewidths=0.5
)
plt.title('Correlação entre variáveis numéricas')
plt.show()

# %% [markdown]
# # Pré-Processamento e Machine Learning

# %%
# Imports
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, ConfusionMatrixDisplay
from sklearn.compose import ColumnTransformer
import joblib

# %%
# Tira as colunas para evitar vazamento de dados
# A nota final de alguns alunos é zero por eles sairem no meio do ano letivo
# Por isso foram removidas as colunas 'Final_Grade' e 'Grade_2' para evitar atalhos
X = df.drop(columns=['Dropped_Out', 'Final_Grade', 'Grade_2'])
y = df['Dropped_Out']

# %%
# Identifica as colunas categóricas e as númericas
num_cols = X.select_dtypes(include=[np.number]).columns
cat_cols = [col for col in X.columns if col not in num_cols]

# Preprocessamento dos dados
# Transforma as cols cat em numéricas
# Padroniza as cols numéricas
preprocess = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore'), cat_cols),
        ('num', StandardScaler(), num_cols)
    ]
)

# %%
# Divide os dados para teste e treinamento
X_treino, X_teste, y_treino, y_teste = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Pipeline 
pipeline = Pipeline([
    ('preprocess', preprocess),
    ('logreg', LogisticRegression(solver='liblinear', random_state=42, max_iter=1000, class_weight='balanced'))
])

# %%
# Definir o grid de hiperparâmetros para otimização
parametros_grid = {
    'logreg__class_weight': ['balanced'],   # Balanceia o foco pois a taxa de evasão é baixa
    'logreg__C': [0.1, 1, 10],              # Evita overfitting, quanto menor mais genérico
    'logreg__penalty': ['l1', 'l2'],        # Muda as penalidades
    'logreg__max_iter': [5000, 6000]        # Quantidade de iterações
}

# %%
# Configurar o objeto GridSearchCV
grid_search = GridSearchCV(
    pipeline,              # Pipeline com as etapas de pré-processamento e modelo
    parametros_grid,       # Dicionário com as combinações de hiperparâmetros a serem testadas
    cv = 5,                # Número de divisões para validação cruzada (5-fold cross-validation)
    n_jobs = -1,           # Usa todos os núcleos disponíveis do processador para acelerar o processo
    scoring = 'f1',        # Métrica usada para avaliar o desempenho de cada combinação (aqui, f1)
    verbose = 1            # Nível de detalhamento do output durante a execução (1 exibe progresso básico)
)

# %%
# Treinamento com o Pipeline
print("\nIniciando o treinamento do modelo com otimização de hiperparâmetros...\n")
grid_search.fit(X_treino, y_treino)
# Out:
# Iniciando o treinamento do modelo com otimização de hiperparâmetros...
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# C:\Users\pcavalcante\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# C:\Users\pcavalcante\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\linear_model\_logistic.py:1429: UserWarning: Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
#   warnings.warn(
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocess',
# ...

# %%
print("\nMelhores hiperparâmetros encontrados:\n")
print(grid_search.best_params_)
# Out:
# Melhores hiperparâmetros encontrados:
#
# {'logreg__C': 1, 'logreg__class_weight': 'balanced', 'logreg__max_iter': 5000, 'logreg__penalty': 'l1'}

# %%
# Obter o melhor modelo
melhor_modelo = grid_search.best_estimator_

# %% [markdown]
# # Avaliação do Modelo e Interpretação de Métricas

# %%
# Previsões no conjunto de teste
y_pred = melhor_modelo.predict(X_teste)

# %%
# Relatório completo de métricas
# target_names segue a ordem das classes: False (Não Evasão) e True (Evasão)
print("\n--- Relatório de Classificação ---")
print(classification_report(y_teste, y_pred, target_names=['Não Evasão', 'Evasão']))
# Out:
# --- Relatório de Classificação ---
#               precision    recall  f1-score   support
#
#   Não Evasão       0.97      0.89      0.93       169
#       Evasão       0.53      0.81      0.64        26
#
#     accuracy                           0.88       195
#    macro avg       0.75      0.85      0.78       195
# weighted avg       0.91      0.88      0.89       195

# %%
# Visualizar a Matriz de Confusão
ConfusionMatrixDisplay.from_predictions(
    y_teste, y_pred,
    display_labels=['Não Evasão', 'Evasão'],
    cmap='Blues'
)
plt.title("Matriz de Confusão")
plt.xlabel("Classe Prevista")
plt.ylabel("Classe Real")
plt.show()

# %%
# Baixar o arquivo do modelo
joblib.dump(melhor_modelo, 'modelo_evasao.joblib')
# Out:
# ['modelo_evasao.joblib']

# %% [markdown]
# # Teste com dados novos

# %%
novos_alunos = [
    # Aluno 1: F, jovem, notas consistentes, mantém na escola
    ["GP", "F", 15, "U", "GT3", "T", 4, 3, "services", "other", "reputation", "mother", 1, 2, 0, "no", "yes", "no", "yes", "yes", "yes", "yes", "no", 4, 3, 2, 1, 1, 4, 2, 13, 14, 14, False],
    
    # Aluno 2: M, mais velho, muitas faltas e histórico de reprovação -> Caso de Evasão (True)
    ["GP", "M", 18, "R", "GT3", "A", 2, 1, "other", "other", "course", "mother", 3, 1, 2, "no", "no", "no", "no", "yes", "no", "yes", "yes", 3, 4, 5, 4, 3, 2, 16, 7, 6, 5, True],
    
    # Aluno 3: F, pais separados, boas notas e suporte familiar
    ["GP", "F", 16, "U", "LE3", "T", 3, 4, "teacher", "services", "home", "father", 1, 3, 0, "no", "yes", "yes", "no", "yes", "yes", "yes", "no", 5, 2, 3, 1, 1, 5, 0, 15, 15, 16, False],
    
    # Aluno 4: M, jovem, consumo de álcool elevado, mas sem reprovações ainda
    ["GP", "M", 15, "U", "GT3", "T", 2, 2, "other", "other", "home", "mother", 2, 2, 0, "no", "yes", "no", "yes", "yes", "yes", "yes", "no", 4, 4, 4, 3, 2, 3, 4, 11, 10, 11, False],
    
    # Aluno 5: F, rural, tempo de viagem alto, apoio escolar ativo
    ["GP", "F", 17, "R", "GT3", "T", 1, 2, "at_home", "other", "course", "mother", 3, 2, 0, "yes", "yes", "no", "no", "no", "yes", "no", "no", 4, 3, 2, 1, 1, 4, 6, 10, 11, 11, False],
    
    # Aluno 6: M, excelente desempenho acadêmico, pais com alta escolaridade
    ["GP", "M", 16, "U", "LE3", "A", 4, 4, "health", "teacher", "reputation", "father", 1, 4, 0, "no", "yes", "yes", "yes", "yes", "yes", "yes", "no", 5, 3, 2, 1, 1, 5, 0, 18, 17, 18, False],
    
    # Aluno 7: F, 17 anos, começou a faltar muito e desandou nas notas -> Caso de Evasão (True)
    ["GP", "F", 17, "U", "GT3", "T", 2, 2, "other", "services", "course", "mother", 1, 1, 1, "no", "no", "no", "no", "yes", "yes", "yes", "yes", 3, 3, 4, 2, 3, 3, 22, 8, 5, 0, True],
    
    # Aluno 8: M, jovem, família grande, nível de estudo baixo
    ["GP", "M", 15, "U", "GT3", "T", 3, 3, "services", "other", "home", "mother", 1, 1, 0, "no", "no", "no", "no", "yes", "yes", "yes", "no", 4, 5, 3, 2, 1, 4, 2, 12, 11, 12, False],
    
    # Aluno 9: F, 16 anos, em um relacionamento, perfil mediano
    ["GP", "F", 16, "U", "LE3", "T", 4, 2, "teacher", "other", "home", "mother", 1, 2, 0, "no", "yes", "no", "yes", "yes", "yes", "yes", "yes", 4, 2, 3, 1, 2, 2, 4, 13, 12, 13, False],
    
    # Aluno 10: M, 16 anos, suporte escolar e familiar presentes
    ["GP", "M", 16, "U", "GT3", "A", 3, 3, "other", "other", "course", "mother", 2, 2, 0, "yes", "yes", "no", "no", "yes", "yes", "yes", "no", 5, 4, 2, 2, 1, 3, 2, 11, 12, 12, False]
]

# %%
# Carrega o modelo a partir do disco
modelo_evasao_deploy = joblib.load('modelo_evasao.joblib')

# %%
def prever_evasao(lista_novos_alunos):
    # Sem as colunas: Grade_2; Final_Grade; Dropped_Out
    nomes_colunas = [
        'School', 'Gender', 'Age', 'Address', 'Family_Size', 'Parental_Status',
        'Mother_Education', 'Father_Education', 'Mother_Job', 'Father_Job',
        'Reason_for_Choosing_School', 'Guardian', 'Travel_Time', 'Study_Time',
        'Number_of_Failures', 'School_Support', 'Family_Support', 'Extra_Paid_Class',
        'Extra_Curricular_Activities', 'Attended_Nursery', 'Wants_Higher_Education',
        'Internet_Access', 'In_Relationship', 'Family_Relationship', 'Free_Time',
        'Going_Out', 'Weekend_Alcohol_Consumption', 'Weekday_Alcohol_Consumption',
        'Health_Status', 'Number_of_Absences', 'Grade_1'
    ]

    dados_limpos = [aluno[:31] for aluno in lista_novos_alunos]
    df_novos = pd.DataFrame(dados_limpos, columns=nomes_colunas)

    colunas_numericas = [
        'Age', 'Travel_Time', 'Study_Time', 'Number_of_Failures',
        'Free_Time', 'Going_Out', 'Weekend_Alcohol_Consumption',
        'Weekday_Alcohol_Consumption', 'Health_Status',
        'Number_of_Absences', 'Grade_1'
    ]

    # Garante que os dados sejam númericos(e não "18")
    for col in colunas_numericas:
        df_novos[col] = pd.to_numeric(df_novos[col], errors='coerce')

    previsoes = modelo_evasao_deploy.predict(df_novos)

    evasao = ['Não Evasão' if p == 0 else 'Evasão' for p in previsoes]

    print("\n--- Resultados da Previsão ---")
    for i, resultado in enumerate(evasao):
        print(f"Aluno {i+1} -> Predição: {resultado}")

# %%
# Executar a função de deploy com os novos dados
print("\n--- Iniciando Classificação de Novos Alunos ---\n")
prever_evasao(novos_alunos)
# Out:
# --- Iniciando Classificação de Novos Alunos ---
#
#
# --- Resultados da Previsão ---
# Aluno 1 -> Predição: Não Evasão
# Aluno 2 -> Predição: Evasão
# Aluno 3 -> Predição: Não Evasão
# Aluno 4 -> Predição: Não Evasão
# Aluno 5 -> Predição: Não Evasão
# Aluno 6 -> Predição: Não Evasão
# Aluno 7 -> Predição: Evasão
# Aluno 8 -> Predição: Não Evasão
# Aluno 9 -> Predição: Não Evasão
# Aluno 10 -> Predição: Não Evasão
