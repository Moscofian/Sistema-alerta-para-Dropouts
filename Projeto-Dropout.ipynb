# %% [markdown]
# Dataset:
# https://www.kaggle.com/datasets/abdullah0a/student-dropout-analysis-and-prediction-dataset
#
# Licença: MIT
# CC0: Public Domain
#
# ### Descrição das Colunas:
#
# 1. **School (Escola):** Nome da escola frequentada (ex: MS).
# 2. **Gender (Gênero):** Gênero do estudante (ex: M para Masculino, F para Feminino).
# 3. **Age (Idade):** Idade do estudante.
# 4. **Address (Endereço):** Tipo de residência (U para urbana, R para rural).
# 5. **Family_Size (Tamanho_da_Família):** Tamanho da família (GT3 para maior que 3 pessoas, LE3 para menor ou igual a 3 pessoas).
# 6. **Parental_Status (Estado_dos_Pais):** Situação de coabitação dos pais (A para morando juntos, T para morando separados).
# 7. **Mother_Education (Escolaridade_da_Mãe):** Nível de escolaridade da mãe (0 a 4).
# 8. **Father_Education (Escolaridade_do_Pai):** Nível de escolaridade do pai (0 a 4).
# 9. **Mother_Job (Profissão_da_Mãe):** Tipo de trabalho exercido pela mãe.
# 10. **Father_Job (Profissão_do_Pai):** Tipo de trabalho exercido pelo pai.
# 11. **Reason_for_Choosing_School (Motivo_da_Escolha):** Razão pela qual escolheu a escola (ex: curso).
# 12. **Guardian (Responsável):** Responsável legal pelo estudante (ex: mãe).
# 13. **Travel_Time (Tempo_de_Viagem):** Tempo de deslocamento até a escola (em minutos).
# 14. **Study_Time (Tempo_de_Estudo):** Horas de estudo semanais (escala de 1 a 4).
# 15. **Number_of_Failures (Número_de_Reprovações):** Quantidade de reprovações em turmas anteriores.
# 16. **School_Support (Apoio_Escolar):** Se o estudante recebe apoio educacional extra da escola (sim/não).
# 17. **Family_Support (Apoio_Familiar):** Se a família oferece apoio educacional em casa (sim/não).
# 18. **Extra_Paid_Class (Aulas_Particulares):** Participação em aulas extras pagas/reforço (sim/não).
# 19. **Extra_Curricular_Activities (Atividades_Extracurriculares):** Envolvimento em atividades extracurriculares (sim/não).
# 20. **Attended_Nursery (Frequentou_Creche):** Se frequentou a creche/educação infantil quando criança (sim/não).
# 21. **Wants_Higher_Education (Deseja_Ensino_Superior):** Desejo de cursar o ensino superior/faculdade (sim/não).
# 22. **Internet_Access (Acesso_à_Internet):** Disponibilidade de internet em casa (sim/não).
# 23. **In_Relationship (Namorando):** Status de relacionamento amoroso (sim/não).
# 24. **Family_Relationship (Relacionamento_Familiar):** Qualidade das relações familiares (escala de 1 a 5).
# 25. **Free_Time (Tempo_Livre):** Quantidade de tempo livre após a escola (escala de 1 a 5).
# 26. **Going_Out (Sair_com_Amigos):** Frequência de saídas com amigos (escala de 1 a 5).
# 27. **Weekend_Alcohol_Consumption (Consumo_Álcool_Fim_de_Semana):** Consumo de álcool nos fins de semana (escala de 1 a 5).
# 28. **Weekday_Alcohol_Consumption (Consumo_Álcool_Dias_Úteis):** Consumo de álcool em dias úteis (escala de 1 a 5).
# 29. **Health_Status (Estado_de_Saúde):** Avaliação do estado de saúde do estudante (escala de 1 a 5).
# 30. **Number_of_Absences (Número_de_Faltas):** Quantidade total de faltas na escola.
# 31. **Grade_1 (Nota_1):** Nota recebida na primeira avaliação (geralmente primeiro bimestre/trimestre).
# 32. **Grade_2 (Nota_2):** Nota recebida na segunda avaliação.
# 33. **Final_Grade (Nota_Final):** Nota final recebida no fim do ano (G3).
# 34. **Dropped_Out (Evadiu):** Indicador se o aluno abandonou a escola ou não (True para Sim / False para Não).

# %%
# Versão da Linguagem Python
from platform import python_version
print('Versão da Linguagem Python Usada Neste Jupyter Notebook:', python_version())
# Out:
# Versão da Linguagem Python Usada Neste Jupyter Notebook: 3.13.9

# %%
# Imports
# Manipulação de dados
import pandas as pd
# Trabalho com vetores, matrizes e matemática
import numpy as np
# Pacote para gráficos
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Carregando e Compreendendo os Dados

# %%
# Carrega o dataset
df = pd.read_csv('./student dropout.csv')

# %%
# Tamanho do dataset em linhas e colunas
print("Linhas: {} \nColunas: {}".format(*df.shape))
# Out:
# Linhas: 649
# Colunas: 34

# %%
# Mostra as 5 primeiras linhas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df.head()
# Out:
#   School Gender  Age Address Family_Size Parental_Status  Mother_Education  \
# 0     GP      F   18       U         GT3               A                 4
# 1     GP      F   17       U         GT3               T                 1
# 2     GP      F   15       U         LE3               T                 1
# 3     GP      F   15       U         GT3               T                 4
# 4     GP      F   16       U         GT3               T                 3
#
#    Father_Education Mother_Job Father_Job Reason_for_Choosing_School Guardian  \
# 0                 4    at_home    teacher                     course   mother
# 1                 1    at_home      other                     course   father
# 2                 1    at_home      other                      other   mother
# 3                 2     health   services                       home   mother
# 4                 3      other      other                       home   father
#
# ...

# %%
# Mostra 10 linhas aleatórias 
df.sample(10)
# Out:
#     School Gender  Age Address Family_Size Parental_Status  Mother_Education  \
# 415     GP      F   19       U         GT3               T                 4
# 152     GP      M   16       U         LE3               T                 2
# 115     GP      M   16       U         GT3               T                 4
# 609     MS      F   18       U         GT3               T                 1
# 473     MS      M   16       U         LE3               T                 2
# 468     MS      M   15       U         GT3               T                 2
# 38      GP      F   15       R         GT3               T                 3
# 264     GP      F   17       U         LE3               A                 2
# 151     GP      M   16       U         GT3               T                 4
# 212     GP      F   17       U         GT3               T                 4
#
#      Father_Education Mother_Job Father_Job Reason_for_Choosing_School  \
# ...

# %% [markdown]
# ## Análise Exploratória de Dados (EDA)

# %%
# Informações do dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   School                       649 non-null    object
#  1   Gender                       649 non-null    object
#  2   Age                          649 non-null    int64
#  3   Address                      649 non-null    object
#  4   Family_Size                  649 non-null    object
#  5   Parental_Status              649 non-null    object
#  6   Mother_Education             649 non-null    int64
#  7   Father_Education             649 non-null    int64
#  8   Mother_Job                   649 non-null    object
#  9   Father_Job                   649 non-null    object
#  10  Reason_for_Choosing_School   649 non-null    object
#  11  Guardian                     649 non-null    object
#  12  Travel_Time                  649 non-null    int64
# ...

# %%
# Não tem valores null
df.isnull().sum()
# Out:
# School                         0
# Gender                         0
# Age                            0
# Address                        0
# Family_Size                    0
# Parental_Status                0
# Mother_Education               0
# Father_Education               0
# Mother_Job                     0
# Father_Job                     0
# Reason_for_Choosing_School     0
# Guardian                       0
# Travel_Time                    0
# Study_Time                     0
# Number_of_Failures             0
# School_Support                 0
# Family_Support                 0
# Extra_Paid_Class               0
# Extra_Curricular_Activities    0
# Attended_Nursery               0
# Wants_Higher_Education         0
# Internet_Access                0
# In_Relationship                0
# Family_Relationship            0
# Free_Time                      0
# Going_Out                      0
# Weekend_Alcohol_Consumption    0
# Weekday_Alcohol_Consumption    0
# ...

# %%
# Relação entre alunos
print("\nDistribuição das evasões:\n")
situacao = df['Dropped_Out'].map({False: 'Não Evasão', True: 'Evasão'})
ax = sns.countplot(x=situacao, order=['Não Evasão', 'Evasão'])
ax.bar_label(ax.containers[0])
plt.title('Distribuição dos alunos')
plt.xlabel('Situação')
plt.ylabel('Quantidade')
plt.show()
# Out:
# Distribuição das evasões:

# %%
# Relação entre nota final e frequência
plt.figure(figsize=(10, 6))
sns.histplot(df['Final_Grade'], bins=20, kde=True)
plt.title('Distribuição da Nota Final')
plt.xlabel('Nota Final (G3)')
plt.ylabel('Frequência')
plt.show()

# %%
# Taxa de evasão por gênero
situacao = df['Dropped_Out'].map({False: 'Não Evasão', True: 'Evasão'})

fig, ax = plt.subplots(figsize=(8, 5))
sns.countplot(data=df, x='Gender', hue=situacao, hue_order=['Não Evasão', 'Evasão'], ax=ax)

ax.set_title('Taxa de evasão por gênero')
ax.set_xlabel('Gênero')
ax.set_ylabel('Quantidade')

for p in ax.patches:
    ax.annotate(format(p.get_height(), '.0f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha = 'center', va = 'center', 
                xytext = (0, 5), 
                textcoords = 'offset points')

ax.legend(title='Situação')

plt.show()

# %%
# Evasão por idade
situacao = df['Dropped_Out'].map({False: 'Não Evasão', True: 'Evasão'})
ax = sns.countplot(data=df, x='Age', hue=situacao, hue_order=['Não Evasão', 'Evasão'])
ax.legend(title='Situação')
plt.title('Evasão por idade')
plt.xlabel('Idade')
plt.ylabel('Quantidade')
plt.show()

# %%
# Taxa de evasão por faixa de faltas
# Um boxplot aqui é pouco informativo: a distribuição de faltas é muito
# assimétrica e ~35% dos alunos têm zero faltas nos dois grupos.
# Este gráfico responde a pergunta de forma direta:
# quanto mais faltas, maior a chance de evasão?
faixas = pd.cut(
    df['Number_of_Absences'],
    bins=[-1, 0, 5, 10, 20, df['Number_of_Absences'].max()],
    labels=['0', '1-5', '6-10', '11-20', '21+']
)
taxa_evasao = df.groupby(faixas, observed=True)['Dropped_Out'].mean() * 100

ax = taxa_evasao.plot(kind='bar', color=sns.color_palette()[0], rot=0)
ax.bar_label(ax.containers[0], fmt='%.1f%%')
plt.title('Taxa de evasão por faixa de faltas')
plt.xlabel('Faixa de faltas')
plt.ylabel('Taxa de evasão (%)')
plt.ylim(0, 45)
plt.show()
# Obs: a faixa 21+ tem poucos alunos (8), então a taxa dela é menos confiável

# %%
# Heatmap
# Número positivo = diretamente proporcional
# Número negativo = inversamente proporcional
plt.figure(figsize=(12, 8))
sns.heatmap(
    df.corr(numeric_only=True), 
    annot=True, 
    cmap='PuOr', 
    fmt='.2f',
    vmin=-1,
    vmax=1,
    center=0,
    linewidths=0.5
)
plt.title('Correlação entre variáveis numéricas')
plt.show()

# %% [markdown]
# # Pré-Processamento e Machine Learning

# %%
# Imports
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report, ConfusionMatrixDisplay
from sklearn.compose import ColumnTransformer
import joblib

# %%
# Tira as colunas para evitar vazamento de dados
# A nota final de alguns alunos é zero por eles sairem no meio do ano letivo
# Por isso foram removidas as colunas 'Final_Grade' e 'Grade_2' para evitar atalhos
X = df.drop(columns=['Dropped_Out', 'Final_Grade', 'Grade_2'])
y = df['Dropped_Out']

# %%
# Identifica as colunas categóricas e as númericas
num_cols = X.select_dtypes(include=[np.number]).columns
cat_cols = [col for col in X.columns if col not in num_cols]

# Preprocessamento dos dados
# Transforma as cols cat em numéricas
# Padroniza as cols numéricas
preprocess = ColumnTransformer(
    transformers=[
        ('cat', OneHotEncoder(handle_unknown='ignore'), cat_cols),
        ('num', StandardScaler(), num_cols)
    ]
)

# %%
# Divide os dados para teste e treinamento
X_treino, X_teste, y_treino, y_teste = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Pipeline 
pipeline = Pipeline([
    ('preprocess', preprocess),
    ('logreg', LogisticRegression(solver='liblinear', random_state=42, max_iter=1000, class_weight='balanced'))
])

# %%
# Definir o grid de hiperparâmetros para otimização
parametros_grid = {
    'logreg__class_weight': ['balanced'],   # Balanceia o foco pois a taxa de evasão é baixa
    'logreg__C': [0.1, 1, 10],              # Evita overfitting, quanto menor mais genérico
    'logreg__penalty': ['l1', 'l2'],        # Muda as penalidades
    'logreg__max_iter': [5000, 6000]        # Quantidade de iterações
}

# %%
# Configurar o objeto GridSearchCV
grid_search = GridSearchCV(
    pipeline,              # Pipeline com as etapas de pré-processamento e modelo
    parametros_grid,       # Dicionário com as combinações de hiperparâmetros a serem testadas
    cv = 5,                # Número de divisões para validação cruzada (5-fold cross-validation)
    n_jobs = -1,           # Usa todos os núcleos disponíveis do processador para acelerar o processo
    scoring = 'f1',        # Métrica usada para avaliar o desempenho de cada combinação (aqui, f1)
    verbose = 1            # Nível de detalhamento do output durante a execução (1 exibe progresso básico)
)

# %%
# Treinamento com o Pipeline
print("\nIniciando o treinamento do modelo com otimização de hiperparâmetros...\n")
grid_search.fit(X_treino, y_treino)
# Out:
# Iniciando o treinamento do modelo com otimização de hiperparâmetros...
#
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('cat',
#                                                                          OneHotEncoder(handle_unknown='ignore'),
#                                                                          ['School',
#                                                                           'Gender',
#                                                                           'Address',
#                                                                           'Family_Size',
#                                                                           'Parental_Status',
#                                                                           'Mother_Job',
# ...

# %%
print("\nMelhores hiperparâmetros encontrados:\n")
print(grid_search.best_params_)
# Out:
# Melhores hiperparâmetros encontrados:
#
# {'logreg__C': 1, 'logreg__class_weight': 'balanced', 'logreg__max_iter': 5000, 'logreg__penalty': 'l1'}

# %%
# Obter o melhor modelo
melhor_modelo = grid_search.best_estimator_

# %% [markdown]
# # Avaliação do Modelo e Interpretação de Métricas

# %%
# Previsões no conjunto de teste
y_pred = melhor_modelo.predict(X_teste)

# %%
# Relatório completo de métricas
# target_names segue a ordem das classes: False (Não Evasão) e True (Evasão)
print("\n--- Relatório de Classificação ---")
print(classification_report(y_teste, y_pred, target_names=['Não Evasão', 'Evasão']))
# Out:
# --- Relatório de Classificação ---
#               precision    recall  f1-score   support
#
#   Não Evasão       0.97      0.89      0.93       169
#       Evasão       0.53      0.81      0.64        26
#
#     accuracy                           0.88       195
#    macro avg       0.75      0.85      0.78       195
# weighted avg       0.91      0.88      0.89       195

# %%
# Visualizar a Matriz de Confusão
ConfusionMatrixDisplay.from_predictions(
    y_teste, y_pred,
    display_labels=['Não Evasão', 'Evasão'],
    cmap='Blues'
)
plt.title("Matriz de Confusão")
plt.xlabel("Classe Prevista")
plt.ylabel("Classe Real")
plt.show()

# %%
# Baixar o arquivo do modelo
joblib.dump(melhor_modelo, 'modelo_evasao.joblib')
# Out:
# ['modelo_evasao.joblib']

# %% [markdown]
# # Teste com dados novos

# %%
novos_alunos = [
    # Aluno 1: F, jovem, notas consistentes, mantém na escola
    ["GP", "F", 15, "U", "GT3", "T", 4, 3, "services", "other", "reputation", "mother", 1, 2, 0, "no", "yes", "no", "yes", "yes", "yes", "yes", "no", 4, 3, 2, 1, 1, 4, 2, 13, 14, 14, False],
    
    # Aluno 2: M, mais velho, muitas faltas e histórico de reprovação -> Caso de Evasão (True)
    ["GP", "M", 18, "R", "GT3", "A", 2, 1, "other", "other", "course", "mother", 3, 1, 2, "no", "no", "no", "no", "yes", "no", "yes", "yes", 3, 4, 5, 4, 3, 2, 16, 7, 6, 5, True],
    
    # Aluno 3: F, pais separados, boas notas e suporte familiar
    ["GP", "F", 16, "U", "LE3", "T", 3, 4, "teacher", "services", "home", "father", 1, 3, 0, "no", "yes", "yes", "no", "yes", "yes", "yes", "no", 5, 2, 3, 1, 1, 5, 0, 15, 15, 16, False],
    
    # Aluno 4: M, jovem, consumo de álcool elevado, mas sem reprovações ainda
    ["GP", "M", 15, "U", "GT3", "T", 2, 2, "other", "other", "home", "mother", 2, 2, 0, "no", "yes", "no", "yes", "yes", "yes", "yes", "no", 4, 4, 4, 3, 2, 3, 4, 11, 10, 11, False],
    
    # Aluno 5: F, rural, tempo de viagem alto, apoio escolar ativo
    ["GP", "F", 17, "R", "GT3", "T", 1, 2, "at_home", "other", "course", "mother", 3, 2, 0, "yes", "yes", "no", "no", "no", "yes", "no", "no", 4, 3, 2, 1, 1, 4, 6, 10, 11, 11, False],
    
    # Aluno 6: M, excelente desempenho acadêmico, pais com alta escolaridade
    ["GP", "M", 16, "U", "LE3", "A", 4, 4, "health", "teacher", "reputation", "father", 1, 4, 0, "no", "yes", "yes", "yes", "yes", "yes", "yes", "no", 5, 3, 2, 1, 1, 5, 0, 18, 17, 18, False],
    
    # Aluno 7: F, 17 anos, começou a faltar muito e desandou nas notas -> Caso de Evasão (True)
    ["GP", "F", 17, "U", "GT3", "T", 2, 2, "other", "services", "course", "mother", 1, 1, 1, "no", "no", "no", "no", "yes", "yes", "yes", "yes", 3, 3, 4, 2, 3, 3, 22, 8, 5, 0, True],
    
    # Aluno 8: M, jovem, família grande, nível de estudo baixo
    ["GP", "M", 15, "U", "GT3", "T", 3, 3, "services", "other", "home", "mother", 1, 1, 0, "no", "no", "no", "no", "yes", "yes", "yes", "no", 4, 5, 3, 2, 1, 4, 2, 12, 11, 12, False],
    
    # Aluno 9: F, 16 anos, em um relacionamento, perfil mediano
    ["GP", "F", 16, "U", "LE3", "T", 4, 2, "teacher", "other", "home", "mother", 1, 2, 0, "no", "yes", "no", "yes", "yes", "yes", "yes", "yes", 4, 2, 3, 1, 2, 2, 4, 13, 12, 13, False],
    
    # Aluno 10: M, 16 anos, suporte escolar e familiar presentes
    ["GP", "M", 16, "U", "GT3", "A", 3, 3, "other", "other", "course", "mother", 2, 2, 0, "yes", "yes", "no", "no", "yes", "yes", "yes", "no", 5, 4, 2, 2, 1, 3, 2, 11, 12, 12, False],

    # Aluno 11: M, 17 anos, urbano, 3 faltas, perfil estavel
    ["GP", "M", 17, "U", "GT3", "A", 2, 2, "teacher", "at_home", "home", "mother", 2, 2, 0, "no", "yes", "yes", "no", "yes", "yes", "yes", "no", 3, 4, 2, 3, 2, 2, 3, 16, 18, 18, False],

    # Aluno 12: F, 17 anos, urbano, 3 faltas, perfil estavel
    ["GP", "F", 17, "U", "GT3", "T", 4, 2, "at_home", "health", "course", "mother", 1, 4, 0, "no", "yes", "yes", "no", "no", "yes", "yes", "no", 3, 3, 2, 3, 1, 4, 3, 14, 14, 13, False],

    # Aluno 13: F, 16 anos, urbano, 2 faltas, perfil estavel
    ["MS", "F", 16, "U", "GT3", "T", 4, 2, "at_home", "at_home", "home", "father", 1, 4, 0, "no", "yes", "no", "yes", "yes", "no", "yes", "no", 5, 3, 1, 1, 1, 2, 2, 12, 14, 13, False],

    # Aluno 14: F, 18 anos, urbano, 3 reprov., 17 faltas -> Caso de Evasao (True)
    ["GP", "F", 18, "U", "LE3", "T", 3, 1, "services", "health", "home", "mother", 2, 2, 3, "no", "yes", "no", "no", "yes", "no", "yes", "yes", 1, 2, 3, 5, 3, 1, 17, 6, 3, 2, True],

    # Aluno 15: M, 15 anos, urbano, 1 faltas, perfil estavel
    ["GP", "M", 15, "U", "LE3", "T", 1, 1, "at_home", "other", "course", "father", 3, 3, 0, "no", "yes", "yes", "yes", "yes", "no", "yes", "no", 4, 3, 4, 3, 2, 3, 1, 9, 11, 13, False],

    # Aluno 16: M, 16 anos, urbano, 1 faltas, perfil estavel
    ["GP", "M", 16, "U", "LE3", "T", 1, 1, "at_home", "services", "course", "other", 2, 2, 0, "no", "yes", "no", "no", "yes", "yes", "yes", "no", 3, 4, 3, 1, 2, 5, 1, 16, 16, 14, False],

    # Aluno 17: F, 17 anos, urbano, 2 reprov., 19 faltas -> Caso de Evasao (True)
    ["GP", "F", 17, "U", "GT3", "T", 2, 2, "health", "other", "course", "other", 2, 1, 2, "no", "no", "no", "no", "no", "no", "no", "yes", 2, 4, 3, 2, 2, 3, 19, 6, 7, 4, True],

    # Aluno 18: M, 15 anos, rural, 7 faltas, perfil estavel
    ["GP", "M", 15, "R", "LE3", "T", 1, 3, "health", "at_home", "other", "mother", 2, 3, 0, "no", "yes", "yes", "yes", "yes", "yes", "no", "no", 4, 4, 2, 2, 1, 2, 7, 9, 9, 8, False],

    # Aluno 19: M, 22 anos, rural, 3 reprov., 19 faltas -> Caso de Evasao (True)
    ["GP", "M", 22, "R", "LE3", "A", 1, 3, "health", "services", "home", "mother", 1, 1, 3, "no", "no", "no", "no", "yes", "yes", "no", "yes", 1, 5, 3, 3, 4, 3, 19, 6, 3, 0, True],

    # Aluno 20: F, 15 anos, rural, 5 faltas, perfil estavel
    ["GP", "F", 15, "R", "GT3", "T", 1, 3, "at_home", "other", "other", "mother", 1, 4, 0, "yes", "yes", "no", "yes", "yes", "yes", "yes", "no", 4, 2, 4, 1, 1, 4, 5, 14, 16, 16, False],

    # Aluno 21: M, 16 anos, urbano, 1 faltas, perfil estavel
    ["GP", "M", 16, "U", "GT3", "T", 3, 4, "at_home", "health", "reputation", "mother", 1, 1, 0, "no", "yes", "no", "yes", "yes", "yes", "yes", "no", 5, 2, 1, 2, 2, 2, 1, 12, 11, 9, False],

    # Aluno 22: F, 19 anos, urbano, 0 reprov., 27 faltas -> Caso de Evasao (True)
    ["MS", "F", 19, "U", "LE3", "T", 3, 1, "teacher", "services", "reputation", "father", 2, 2, 0, "no", "no", "no", "no", "yes", "no", "yes", "yes", 2, 2, 4, 3, 4, 5, 27, 8, 7, 6, True],

    # Aluno 23: M, 17 anos, rural, 8 faltas, perfil estavel
    ["MS", "M", 17, "R", "LE3", "T", 4, 2, "services", "services", "home", "mother", 1, 1, 0, "no", "yes", "no", "yes", "yes", "yes", "yes", "yes", 4, 3, 4, 2, 1, 3, 8, 18, 16, 18, False],

    # Aluno 24: M, 18 anos, urbano, 3 faltas, perfil estavel
    ["GP", "M", 18, "U", "GT3", "A", 2, 3, "services", "other", "home", "father", 1, 1, 0, "no", "yes", "yes", "yes", "yes", "yes", "yes", "no", 5, 4, 1, 1, 2, 3, 3, 15, 15, 14, False],

    # Aluno 25: M, 15 anos, urbano, 1 faltas, perfil estavel
    ["GP", "M", 15, "U", "LE3", "T", 1, 3, "services", "services", "reputation", "father", 1, 1, 1, "yes", "yes", "yes", "no", "yes", "yes", "yes", "yes", 3, 3, 3, 2, 1, 2, 1, 9, 9, 11, False],

    # Aluno 26: F, 15 anos, urbano, 8 faltas, perfil estavel
    ["MS", "F", 15, "U", "GT3", "T", 1, 3, "health", "at_home", "other", "mother", 1, 3, 0, "no", "yes", "yes", "yes", "yes", "yes", "no", "no", 3, 3, 2, 3, 2, 5, 8, 18, 18, 18, False],

    # Aluno 27: M, 18 anos, urbano, 0 faltas, perfil estavel
    ["GP", "M", 18, "U", "GT3", "T", 3, 2, "teacher", "other", "course", "mother", 1, 2, 0, "no", "yes", "no", "no", "yes", "yes", "yes", "no", 5, 2, 4, 3, 2, 5, 0, 15, 14, 14, False],

    # Aluno 28: M, 17 anos, urbano, 1 faltas, perfil estavel
    ["GP", "M", 17, "U", "LE3", "T", 3, 2, "at_home", "at_home", "other", "father", 1, 2, 0, "no", "no", "yes", "yes", "yes", "yes", "no", "no", 4, 2, 2, 2, 1, 4, 1, 17, 16, 16, False],

    # Aluno 29: F, 18 anos, urbano, 4 faltas, perfil estavel
    ["GP", "F", 18, "U", "LE3", "T", 4, 4, "services", "other", "other", "mother", 1, 4, 0, "no", "yes", "yes", "yes", "yes", "yes", "yes", "no", 4, 2, 2, 1, 2, 3, 4, 16, 16, 18, False],

    # Aluno 30: F, 17 anos, urbano, 7 faltas, perfil estavel
    ["GP", "F", 17, "U", "LE3", "A", 1, 2, "other", "teacher", "home", "mother", 1, 2, 0, "no", "no", "yes", "yes", "yes", "yes", "no", "yes", 3, 3, 2, 2, 1, 3, 7, 10, 8, 8, False],

    # Aluno 31: M, 18 anos, urbano, 6 faltas, perfil estavel
    ["GP", "M", 18, "U", "GT3", "T", 4, 1, "services", "other", "other", "mother", 1, 4, 0, "no", "yes", "yes", "no", "no", "yes", "yes", "no", 4, 4, 1, 1, 2, 5, 6, 15, 16, 14, False],

    # Aluno 32: M, 21 anos, urbano, 1 reprov., 18 faltas -> Caso de Evasao (True)
    ["GP", "M", 21, "U", "LE3", "T", 3, 0, "services", "at_home", "other", "father", 4, 1, 1, "yes", "no", "no", "no", "yes", "no", "yes", "yes", 3, 5, 5, 5, 1, 2, 18, 5, 3, 1, True],

    # Aluno 33: F, 15 anos, urbano, 2 faltas, perfil estavel
    ["GP", "F", 15, "U", "GT3", "T", 4, 1, "teacher", "teacher", "home", "mother", 2, 2, 1, "no", "no", "yes", "yes", "yes", "yes", "yes", "yes", 5, 4, 2, 1, 2, 5, 2, 9, 9, 9, False],

    # Aluno 34: M, 18 anos, rural, 0 faltas, perfil estavel
    ["MS", "M", 18, "R", "GT3", "T", 3, 2, "services", "health", "reputation", "mother", 3, 2, 0, "no", "yes", "yes", "yes", "no", "yes", "no", "no", 5, 2, 4, 1, 1, 4, 0, 16, 14, 13, False],

    # Aluno 35: M, 17 anos, urbano, 2 faltas, perfil estavel
    ["GP", "M", 17, "U", "GT3", "T", 4, 1, "teacher", "health", "reputation", "father", 2, 2, 0, "no", "yes", "yes", "no", "yes", "yes", "yes", "yes", 4, 2, 1, 2, 1, 4, 2, 12, 14, 15, False],

    # Aluno 36: F, 16 anos, urbano, 3 faltas, perfil estavel
    ["GP", "F", 16, "U", "GT3", "T", 4, 3, "other", "other", "home", "mother", 1, 3, 0, "no", "yes", "no", "yes", "no", "no", "yes", "no", 5, 3, 4, 2, 1, 5, 3, 18, 18, 19, False],

    # Aluno 37: M, 18 anos, urbano, 0 faltas, perfil estavel
    ["GP", "M", 18, "U", "GT3", "T", 3, 2, "health", "teacher", "course", "father", 2, 2, 0, "no", "no", "no", "no", "yes", "yes", "no", "no", 4, 3, 1, 3, 2, 3, 0, 15, 14, 13, False],

    # Aluno 38: M, 22 anos, urbano, 0 reprov., 31 faltas -> Caso de Evasao (True)
    ["MS", "M", 22, "U", "LE3", "T", 2, 2, "other", "at_home", "reputation", "mother", 1, 1, 0, "no", "yes", "no", "no", "yes", "no", "yes", "yes", 4, 2, 4, 2, 4, 3, 31, 7, 7, 5, True],

    # Aluno 39: M, 15 anos, urbano, 0 faltas, perfil estavel
    ["GP", "M", 15, "U", "LE3", "T", 4, 3, "health", "services", "home", "father", 2, 1, 0, "yes", "no", "yes", "yes", "yes", "yes", "yes", "no", 5, 4, 4, 3, 1, 5, 0, 13, 11, 11, False],

    # Aluno 40: F, 15 anos, rural, 7 faltas, perfil estavel
    ["GP", "F", 15, "R", "GT3", "T", 4, 3, "health", "health", "other", "mother", 1, 1, 0, "no", "no", "no", "no", "yes", "yes", "yes", "yes", 5, 2, 1, 3, 1, 3, 7, 18, 16, 16, False],

    # Aluno 41: F, 20 anos, urbano, 0 reprov., 22 faltas -> Caso de Evasao (True)
    ["GP", "F", 20, "U", "LE3", "T", 2, 0, "services", "services", "home", "mother", 2, 1, 0, "no", "yes", "yes", "no", "yes", "no", "yes", "yes", 1, 4, 4, 2, 1, 4, 22, 9, 10, 5, True],

    # Aluno 42: F, 18 anos, urbano, 3 faltas, perfil estavel
    ["GP", "F", 18, "U", "GT3", "T", 3, 4, "at_home", "at_home", "other", "mother", 1, 2, 0, "yes", "no", "no", "no", "no", "yes", "no", "no", 4, 3, 4, 3, 1, 4, 3, 14, 13, 14, False],

    # Aluno 43: F, 17 anos, urbano, 2 faltas, perfil estavel
    ["MS", "F", 17, "U", "LE3", "T", 1, 4, "teacher", "teacher", "course", "mother", 1, 3, 0, "no", "no", "no", "no", "yes", "yes", "yes", "no", 3, 2, 3, 3, 2, 2, 2, 15, 17, 19, False],

    # Aluno 44: M, 15 anos, urbano, 4 faltas, perfil estavel
    ["GP", "M", 15, "U", "GT3", "T", 2, 2, "services", "teacher", "other", "father", 1, 2, 0, "no", "yes", "no", "yes", "yes", "yes", "yes", "no", 5, 4, 1, 1, 1, 3, 4, 13, 14, 15, False],

    # Aluno 45: M, 17 anos, urbano, 3 faltas, perfil estavel
    ["GP", "M", 17, "U", "GT3", "T", 1, 2, "other", "teacher", "reputation", "mother", 1, 2, 0, "no", "yes", "yes", "yes", "yes", "yes", "yes", "yes", 4, 4, 2, 3, 2, 2, 3, 9, 10, 8, False],

    # Aluno 46: M, 16 anos, urbano, 1 faltas, perfil estavel
    ["GP", "M", 16, "U", "GT3", "T", 4, 3, "health", "at_home", "other", "mother", 1, 3, 0, "no", "yes", "yes", "yes", "yes", "yes", "yes", "no", 3, 4, 2, 2, 2, 3, 1, 12, 11, 13, False],

    # Aluno 47: M, 17 anos, urbano, 4 faltas, perfil estavel
    ["GP", "M", 17, "U", "GT3", "T", 2, 4, "health", "at_home", "other", "father", 1, 2, 0, "no", "yes", "no", "yes", "yes", "yes", "yes", "yes", 3, 4, 4, 2, 1, 5, 4, 18, 19, 19, False],

    # Aluno 48: M, 18 anos, rural, 7 faltas, perfil estavel
    ["GP", "M", 18, "R", "GT3", "T", 2, 3, "teacher", "at_home", "reputation", "mother", 1, 2, 0, "no", "yes", "no", "no", "yes", "yes", "yes", "yes", 5, 4, 2, 2, 1, 3, 7, 19, 19, 18, False],

    # Aluno 49: M, 18 anos, urbano, 4 faltas, perfil estavel
    ["GP", "M", 18, "U", "GT3", "T", 3, 1, "services", "at_home", "course", "father", 1, 2, 0, "no", "yes", "yes", "yes", "yes", "yes", "yes", "no", 5, 4, 1, 3, 2, 3, 4, 11, 13, 12, False],

    # Aluno 50: F, 20 anos, rural, 1 reprov., 27 faltas -> Caso de Evasao (True)
    ["GP", "F", 20, "R", "GT3", "T", 1, 2, "at_home", "other", "home", "father", 4, 3, 1, "no", "no", "no", "no", "no", "no", "yes", "yes", 2, 3, 4, 2, 4, 3, 27, 4, 5, 4, True],

    # Aluno 51: F, 18 anos, urbano, 3 faltas, perfil estavel
    ["GP", "F", 18, "U", "LE3", "T", 3, 1, "health", "health", "home", "mother", 1, 2, 0, "no", "yes", "yes", "yes", "yes", "yes", "yes", "yes", 3, 3, 4, 3, 1, 5, 3, 10, 8, 8, False],

    # Aluno 52: M, 21 anos, urbano, 2 reprov., 27 faltas -> Caso de Evasao (True)
    ["GP", "M", 21, "U", "GT3", "T", 3, 0, "at_home", "services", "reputation", "mother", 1, 2, 2, "no", "no", "no", "no", "yes", "yes", "yes", "no", 2, 2, 5, 4, 1, 5, 27, 3, 2, 0, True],

    # Aluno 53: M, 17 anos, urbano, 2 faltas, perfil estavel
    ["MS", "M", 17, "U", "GT3", "T", 2, 1, "at_home", "health", "course", "mother", 1, 2, 0, "no", "no", "no", "yes", "yes", "yes", "yes", "no", 3, 3, 2, 1, 1, 2, 2, 17, 18, 18, False],

    # Aluno 54: F, 18 anos, rural, 9 faltas, perfil estavel
    ["GP", "F", 18, "R", "GT3", "T", 4, 3, "services", "at_home", "reputation", "mother", 3, 2, 0, "no", "yes", "no", "no", "yes", "yes", "yes", "no", 4, 2, 1, 2, 2, 4, 9, 11, 12, 12, False],

    # Aluno 55: M, 16 anos, urbano, 0 reprov., 28 faltas -> Caso de Evasao (True)
    ["GP", "M", 16, "U", "GT3", "T", 3, 2, "services", "other", "course", "father", 2, 3, 0, "no", "no", "yes", "yes", "no", "no", "yes", "no", 2, 5, 4, 4, 4, 1, 28, 5, 5, 2, True],

    # Aluno 56: F, 17 anos, rural, 6 faltas, perfil estavel
    ["GP", "F", 17, "R", "GT3", "T", 3, 4, "teacher", "health", "course", "mother", 1, 3, 0, "no", "yes", "yes", "yes", "yes", "yes", "no", "no", 4, 4, 3, 3, 1, 4, 6, 19, 18, 18, False],

    # Aluno 57: F, 18 anos, rural, 9 faltas, perfil estavel
    ["GP", "F", 18, "R", "GT3", "T", 2, 1, "health", "other", "other", "mother", 1, 2, 0, "no", "yes", "yes", "no", "yes", "yes", "yes", "no", 5, 3, 2, 3, 1, 3, 9, 9, 8, 10, False],

    # Aluno 58: M, 15 anos, rural, 4 faltas, perfil estavel
    ["GP", "M", 15, "R", "GT3", "A", 3, 2, "at_home", "services", "other", "mother", 2, 2, 0, "no", "yes", "no", "yes", "no", "yes", "yes", "no", 5, 3, 1, 1, 1, 2, 4, 18, 19, 19, False],

    # Aluno 59: M, 18 anos, urbano, 1 reprov., 18 faltas -> Caso de Evasao (True)
    ["MS", "M", 18, "U", "GT3", "T", 3, 0, "at_home", "at_home", "reputation", "father", 1, 1, 1, "no", "yes", "no", "no", "yes", "no", "yes", "yes", 3, 2, 4, 3, 4, 1, 18, 10, 7, 3, True],

    # Aluno 60: M, 17 anos, rural, 6 faltas, perfil estavel
    ["GP", "M", 17, "R", "GT3", "A", 2, 2, "at_home", "services", "other", "father", 1, 2, 0, "no", "yes", "no", "yes", "no", "yes", "yes", "yes", 4, 4, 4, 2, 1, 2, 6, 14, 15, 15, False],

    # Aluno 61: F, 15 anos, urbano, 4 faltas, perfil estavel
    ["GP", "F", 15, "U", "GT3", "T", 2, 1, "other", "teacher", "other", "mother", 1, 3, 0, "no", "no", "yes", "yes", "yes", "yes", "yes", "no", 4, 4, 4, 1, 1, 4, 4, 18, 18, 19, False],

    # Aluno 62: M, 18 anos, urbano, 0 faltas, perfil estavel
    ["MS", "M", 18, "U", "GT3", "T", 3, 1, "services", "teacher", "course", "mother", 1, 2, 0, "no", "yes", "yes", "yes", "yes", "yes", "yes", "no", 4, 2, 2, 1, 1, 3, 0, 11, 12, 11, False],

    # Aluno 63: M, 20 anos, rural, 1 reprov., 19 faltas -> Caso de Evasao (True)
    ["GP", "M", 20, "R", "LE3", "T", 2, 3, "services", "other", "home", "mother", 4, 1, 1, "no", "yes", "no", "no", "no", "no", "no", "no", 2, 3, 4, 4, 2, 3, 19, 6, 7, 7, True],

    # Aluno 64: M, 17 anos, urbano, 1 faltas, perfil estavel
    ["GP", "M", 17, "U", "GT3", "T", 2, 3, "health", "at_home", "reputation", "father", 1, 4, 0, "no", "no", "no", "yes", "yes", "yes", "yes", "yes", 3, 4, 2, 1, 1, 3, 1, 14, 15, 13, False],

    # Aluno 65: F, 22 anos, urbano, 3 reprov., 11 faltas -> Caso de Evasao (True)
    ["MS", "F", 22, "U", "LE3", "T", 2, 2, "teacher", "at_home", "home", "mother", 3, 2, 3, "yes", "no", "no", "no", "no", "no", "yes", "no", 2, 2, 4, 5, 2, 3, 11, 3, 1, 0, True],

    # Aluno 66: M, 18 anos, urbano, 3 faltas, perfil estavel
    ["MS", "M", 18, "U", "LE3", "T", 3, 2, "health", "at_home", "home", "mother", 2, 2, 0, "no", "no", "yes", "yes", "yes", "yes", "yes", "no", 5, 3, 4, 3, 2, 2, 3, 11, 12, 12, False],

    # Aluno 67: F, 17 anos, urbano, 10 faltas, perfil estavel
    ["GP", "F", 17, "U", "GT3", "T", 3, 2, "services", "teacher", "course", "mother", 1, 1, 0, "no", "yes", "no", "no", "yes", "yes", "no", "yes", 5, 2, 2, 1, 2, 3, 10, 14, 15, 17, False],

    # Aluno 68: F, 17 anos, rural, 3 faltas, perfil estavel
    ["MS", "F", 17, "R", "GT3", "T", 1, 1, "services", "other", "reputation", "father", 1, 2, 0, "no", "yes", "yes", "yes", "yes", "yes", "yes", "yes", 5, 3, 1, 2, 1, 5, 3, 16, 16, 14, False],

    # Aluno 69: F, 16 anos, urbano, 3 reprov., 15 faltas -> Caso de Evasao (True)
    ["MS", "F", 16, "U", "GT3", "T", 3, 0, "health", "at_home", "course", "mother", 3, 1, 3, "no", "no", "no", "no", "no", "no", "no", "no", 4, 2, 5, 3, 3, 1, 15, 9, 9, 5, True],

    # Aluno 70: M, 16 anos, urbano, 0 faltas, perfil estavel
    ["GP", "M", 16, "U", "LE3", "T", 4, 3, "health", "teacher", "home", "mother", 1, 2, 0, "no", "yes", "no", "no", "no", "yes", "yes", "yes", 5, 2, 4, 3, 1, 3, 0, 17, 16, 14, False],

    # Aluno 71: F, 17 anos, rural, 1 reprov., 19 faltas -> Caso de Evasao (True)
    ["MS", "F", 17, "R", "LE3", "T", 2, 1, "services", "health", "other", "mother", 2, 1, 1, "no", "no", "no", "yes", "no", "no", "yes", "yes", 4, 4, 5, 5, 4, 2, 19, 9, 6, 5, True],

    # Aluno 72: M, 19 anos, rural, 1 reprov., 20 faltas -> Caso de Evasao (True)
    ["MS", "M", 19, "R", "GT3", "T", 1, 3, "health", "at_home", "reputation", "mother", 2, 1, 1, "yes", "no", "no", "no", "no", "yes", "yes", "no", 1, 2, 3, 3, 4, 2, 20, 7, 3, 0, True],

    # Aluno 73: M, 20 anos, rural, 2 reprov., 17 faltas -> Caso de Evasao (True)
    ["GP", "M", 20, "R", "GT3", "T", 2, 2, "teacher", "teacher", "home", "mother", 4, 1, 2, "no", "yes", "no", "no", "no", "no", "no", "yes", 2, 4, 4, 5, 1, 5, 17, 5, 1, 0, True],

    # Aluno 74: M, 18 anos, urbano, 6 faltas, perfil estavel
    ["GP", "M", 18, "U", "GT3", "T", 3, 3, "at_home", "health", "home", "mother", 2, 2, 0, "no", "yes", "no", "yes", "yes", "yes", "yes", "no", 5, 2, 1, 1, 1, 2, 6, 12, 10, 9, False],

    # Aluno 75: M, 15 anos, urbano, 2 faltas, perfil estavel
    ["GP", "M", 15, "U", "GT3", "A", 1, 4, "health", "health", "reputation", "father", 1, 2, 0, "no", "yes", "no", "no", "yes", "yes", "yes", "yes", 3, 2, 2, 3, 2, 4, 2, 15, 16, 18, False],

    # Aluno 76: F, 19 anos, urbano, 0 reprov., 28 faltas -> Caso de Evasao (True)
    ["GP", "F", 19, "U", "LE3", "T", 3, 0, "at_home", "health", "reputation", "mother", 1, 2, 0, "no", "no", "no", "no", "no", "no", "no", "yes", 4, 4, 3, 2, 3, 5, 28, 3, 0, 0, True],

    # Aluno 77: M, 17 anos, rural, 9 faltas, perfil estavel
    ["GP", "M", 17, "R", "GT3", "T", 4, 2, "services", "at_home", "reputation", "mother", 2, 3, 0, "no", "yes", "yes", "yes", "yes", "yes", "yes", "no", 4, 2, 3, 2, 2, 3, 9, 15, 14, 16, False],

    # Aluno 78: M, 18 anos, rural, 0 faltas, perfil estavel
    ["GP", "M", 18, "R", "LE3", "T", 3, 3, "teacher", "teacher", "home", "mother", 1, 1, 0, "no", "yes", "yes", "yes", "yes", "yes", "yes", "yes", 4, 4, 1, 3, 2, 5, 0, 10, 12, 11, False],

    # Aluno 79: M, 18 anos, urbano, 4 faltas, perfil estavel
    ["GP", "M", 18, "U", "GT3", "T", 3, 4, "other", "health", "home", "mother", 1, 3, 0, "no", "no", "yes", "no", "yes", "yes", "yes", "no", 5, 3, 3, 2, 2, 5, 4, 18, 17, 18, False],

    # Aluno 80: M, 18 anos, urbano, 3 reprov., 17 faltas -> Caso de Evasao (True)
    ["MS", "M", 18, "U", "GT3", "T", 3, 2, "services", "services", "home", "mother", 4, 1, 3, "no", "no", "no", "no", "yes", "no", "no", "yes", 3, 2, 4, 5, 2, 3, 17, 7, 8, 4, True],

    # Aluno 81: M, 20 anos, urbano, 1 reprov., 26 faltas -> Caso de Evasao (True)
    ["GP", "M", 20, "U", "GT3", "A", 0, 2, "services", "services", "reputation", "father", 1, 1, 1, "no", "yes", "no", "no", "no", "no", "no", "yes", 4, 2, 3, 2, 3, 2, 26, 6, 5, 2, True],

    # Aluno 82: F, 15 anos, urbano, 4 faltas, perfil estavel
    ["GP", "F", 15, "U", "GT3", "T", 2, 3, "services", "health", "course", "mother", 1, 2, 0, "no", "yes", "yes", "no", "yes", "yes", "yes", "yes", 4, 4, 1, 3, 1, 3, 4, 14, 16, 17, False],

    # Aluno 83: F, 18 anos, urbano, 4 faltas, perfil estavel
    ["GP", "F", 18, "U", "GT3", "T", 4, 4, "other", "teacher", "home", "father", 1, 2, 0, "no", "no", "no", "no", "yes", "yes", "yes", "yes", 5, 3, 3, 3, 2, 5, 4, 16, 18, 17, False],

    # Aluno 84: F, 18 anos, urbano, 8 faltas, perfil estavel
    ["GP", "F", 18, "U", "GT3", "T", 4, 2, "services", "services", "home", "mother", 1, 2, 0, "no", "no", "no", "yes", "yes", "yes", "yes", "no", 5, 2, 3, 1, 2, 3, 8, 17, 18, 19, False],

    # Aluno 85: M, 15 anos, urbano, 10 faltas, perfil estavel
    ["GP", "M", 15, "U", "GT3", "T", 3, 2, "services", "other", "other", "father", 1, 2, 0, "no", "no", "no", "yes", "yes", "yes", "yes", "no", 3, 4, 4, 3, 1, 5, 10, 12, 12, 10, False],

    # Aluno 86: F, 18 anos, urbano, 2 faltas, perfil estavel
    ["GP", "F", 18, "U", "LE3", "T", 2, 2, "other", "health", "other", "mother", 2, 3, 0, "no", "yes", "no", "yes", "no", "yes", "yes", "no", 5, 4, 1, 1, 2, 2, 2, 11, 10, 9, False],

    # Aluno 87: M, 16 anos, urbano, 3 reprov., 16 faltas -> Caso de Evasao (True)
    ["GP", "M", 16, "U", "GT3", "T", 0, 3, "other", "other", "reputation", "mother", 3, 2, 3, "no", "no", "no", "no", "no", "yes", "no", "no", 3, 2, 5, 5, 2, 4, 16, 10, 8, 5, True],

    # Aluno 88: F, 15 anos, urbano, 1 faltas, perfil estavel
    ["GP", "F", 15, "U", "GT3", "T", 1, 4, "at_home", "at_home", "course", "father", 1, 4, 0, "no", "no", "yes", "no", "no", "yes", "yes", "no", 4, 2, 3, 2, 1, 4, 1, 13, 12, 13, False],

    # Aluno 89: M, 17 anos, urbano, 7 faltas, perfil estavel
    ["GP", "M", 17, "U", "GT3", "T", 1, 4, "teacher", "services", "course", "mother", 2, 2, 0, "yes", "no", "yes", "yes", "yes", "yes", "yes", "no", 5, 4, 2, 1, 1, 3, 7, 19, 18, 19, False],

    # Aluno 90: F, 18 anos, rural, 0 faltas, perfil estavel
    ["MS", "F", 18, "R", "GT3", "T", 3, 2, "teacher", "at_home", "other", "father", 1, 3, 0, "no", "no", "yes", "no", "yes", "yes", "no", "yes", 5, 4, 2, 3, 2, 4, 0, 10, 9, 10, False],

    # Aluno 91: F, 17 anos, rural, 0 faltas, perfil estavel
    ["GP", "F", 17, "R", "LE3", "T", 2, 4, "other", "services", "reputation", "father", 3, 3, 0, "yes", "yes", "yes", "yes", "yes", "yes", "yes", "no", 4, 3, 4, 1, 1, 4, 0, 12, 11, 13, False],

    # Aluno 92: F, 16 anos, urbano, 0 reprov., 10 faltas -> Caso de Evasao (True)
    ["GP", "F", 16, "U", "GT3", "A", 3, 0, "teacher", "at_home", "home", "mother", 4, 2, 0, "no", "no", "no", "yes", "yes", "yes", "yes", "yes", 3, 3, 4, 3, 3, 1, 10, 8, 7, 4, True],

    # Aluno 93: F, 18 anos, urbano, 2 reprov., 17 faltas -> Caso de Evasao (True)
    ["GP", "F", 18, "U", "GT3", "T", 1, 2, "other", "at_home", "home", "father", 1, 2, 2, "yes", "no", "yes", "no", "yes", "yes", "yes", "no", 2, 2, 5, 5, 2, 3, 17, 9, 10, 7, True],

    # Aluno 94: F, 18 anos, urbano, 0 faltas, perfil estavel
    ["GP", "F", 18, "U", "LE3", "T", 1, 4, "at_home", "services", "course", "father", 2, 3, 0, "yes", "yes", "yes", "yes", "yes", "yes", "yes", "no", 4, 2, 2, 1, 1, 5, 0, 19, 17, 17, False],

    # Aluno 95: M, 16 anos, urbano, 7 faltas, perfil estavel
    ["MS", "M", 16, "U", "GT3", "T", 3, 1, "services", "other", "course", "mother", 1, 2, 0, "no", "no", "yes", "no", "yes", "yes", "yes", "no", 5, 4, 1, 2, 1, 3, 7, 15, 15, 15, False],

    # Aluno 96: F, 19 anos, urbano, 3 reprov., 21 faltas -> Caso de Evasao (True)
    ["GP", "F", 19, "U", "LE3", "T", 2, 3, "other", "other", "reputation", "mother", 1, 1, 3, "no", "yes", "no", "yes", "yes", "no", "no", "no", 1, 3, 4, 3, 1, 2, 21, 9, 9, 4, True],

    # Aluno 97: F, 15 anos, urbano, 5 faltas, perfil estavel
    ["MS", "F", 15, "U", "GT3", "T", 4, 1, "services", "at_home", "home", "father", 2, 1, 0, "no", "no", "yes", "no", "yes", "yes", "yes", "no", 4, 2, 1, 1, 1, 5, 5, 14, 12, 10, False],

    # Aluno 98: M, 17 anos, rural, 2 faltas, perfil estavel
    ["GP", "M", 17, "R", "GT3", "T", 2, 2, "teacher", "other", "home", "father", 1, 2, 0, "no", "yes", "no", "yes", "no", "yes", "yes", "no", 4, 2, 2, 3, 1, 5, 2, 16, 16, 18, False],

    # Aluno 99: F, 16 anos, urbano, 0 reprov., 20 faltas -> Caso de Evasao (True)
    ["GP", "F", 16, "U", "GT3", "T", 3, 2, "other", "teacher", "other", "father", 2, 3, 0, "no", "yes", "no", "no", "yes", "no", "yes", "no", 4, 4, 3, 3, 2, 5, 20, 8, 8, 3, True],

    # Aluno 100: F, 18 anos, rural, 7 faltas, perfil estavel
    ["GP", "F", 18, "R", "LE3", "A", 1, 1, "at_home", "other", "home", "mother", 1, 3, 0, "no", "yes", "no", "no", "yes", "yes", "yes", "no", 3, 2, 2, 3, 1, 2, 7, 14, 15, 17, False],

    # Aluno 101: F, 17 anos, rural, 5 faltas, perfil estavel
    ["GP", "F", 17, "R", "LE3", "T", 2, 3, "health", "other", "reputation", "mother", 1, 2, 0, "no", "no", "yes", "no", "no", "yes", "yes", "no", 5, 2, 2, 3, 2, 3, 5, 11, 11, 9, False],

    # Aluno 102: F, 19 anos, urbano, 0 reprov., 28 faltas -> Caso de Evasao (True)
    ["MS", "F", 19, "U", "LE3", "T", 0, 2, "at_home", "at_home", "other", "mother", 2, 1, 0, "no", "yes", "yes", "no", "no", "no", "no", "yes", 4, 4, 5, 5, 1, 4, 28, 6, 3, 1, True],

    # Aluno 103: M, 21 anos, urbano, 2 reprov., 17 faltas -> Caso de Evasao (True)
    ["GP", "M", 21, "U", "GT3", "T", 0, 0, "teacher", "teacher", "home", "father", 3, 1, 2, "no", "yes", "no", "yes", "no", "yes", "yes", "yes", 2, 5, 5, 4, 3, 3, 17, 4, 0, 0, True],

    # Aluno 104: F, 17 anos, urbano, 1 reprov., 11 faltas -> Caso de Evasao (True)
    ["MS", "F", 17, "U", "GT3", "T", 0, 0, "other", "health", "reputation", "father", 2, 1, 1, "yes", "no", "no", "no", "yes", "no", "yes", "no", 2, 4, 4, 4, 2, 4, 11, 7, 6, 4, True],

    # Aluno 105: F, 16 anos, urbano, 6 faltas, perfil estavel
    ["MS", "F", 16, "U", "GT3", "T", 1, 4, "at_home", "services", "reputation", "mother", 2, 2, 0, "no", "yes", "no", "yes", "yes", "yes", "yes", "no", 5, 4, 2, 1, 2, 3, 6, 11, 9, 10, False],

    # Aluno 106: F, 15 anos, rural, 7 faltas, perfil estavel
    ["GP", "F", 15, "R", "GT3", "A", 4, 4, "teacher", "teacher", "course", "father", 1, 4, 0, "no", "yes", "no", "no", "yes", "yes", "yes", "no", 5, 2, 1, 3, 1, 4, 7, 13, 14, 15, False],

    # Aluno 107: F, 18 anos, urbano, 2 faltas, perfil estavel
    ["GP", "F", 18, "U", "GT3", "T", 3, 2, "services", "health", "course", "father", 1, 2, 0, "no", "yes", "no", "yes", "yes", "yes", "yes", "no", 3, 2, 3, 3, 2, 4, 2, 19, 17, 16, False],

    # Aluno 108: M, 16 anos, urbano, 2 reprov., 31 faltas -> Caso de Evasao (True)
    ["MS", "M", 16, "U", "LE3", "T", 2, 3, "services", "teacher", "home", "father", 2, 2, 2, "no", "yes", "no", "yes", "yes", "yes", "yes", "yes", 2, 4, 4, 5, 4, 1, 31, 3, 0, 0, True],

    # Aluno 109: M, 18 anos, urbano, 2 reprov., 18 faltas -> Caso de Evasao (True)
    ["GP", "M", 18, "U", "GT3", "T", 0, 3, "other", "services", "course", "father", 1, 1, 2, "no", "no", "no", "no", "yes", "no", "yes", "no", 1, 5, 3, 3, 1, 2, 18, 7, 8, 8, True],

    # Aluno 110: M, 15 anos, urbano, 4 faltas, perfil estavel
    ["MS", "M", 15, "U", "GT3", "T", 1, 3, "services", "other", "reputation", "mother", 1, 2, 0, "no", "yes", "yes", "yes", "yes", "yes", "yes", "no", 5, 3, 2, 1, 1, 2, 4, 19, 18, 16, False]
]

# %%
# Carrega o modelo a partir do disco
modelo_evasao_deploy = joblib.load('modelo_evasao.joblib')

# %%
def prever_evasao(lista_novos_alunos):
    # Sem as colunas: Grade_2; Final_Grade; Dropped_Out
    nomes_colunas = [
        'School', 'Gender', 'Age', 'Address', 'Family_Size', 'Parental_Status',
        'Mother_Education', 'Father_Education', 'Mother_Job', 'Father_Job',
        'Reason_for_Choosing_School', 'Guardian', 'Travel_Time', 'Study_Time',
        'Number_of_Failures', 'School_Support', 'Family_Support', 'Extra_Paid_Class',
        'Extra_Curricular_Activities', 'Attended_Nursery', 'Wants_Higher_Education',
        'Internet_Access', 'In_Relationship', 'Family_Relationship', 'Free_Time',
        'Going_Out', 'Weekend_Alcohol_Consumption', 'Weekday_Alcohol_Consumption',
        'Health_Status', 'Number_of_Absences', 'Grade_1'
    ]

    dados_limpos = [aluno[:31] for aluno in lista_novos_alunos]
    df_novos = pd.DataFrame(dados_limpos, columns=nomes_colunas)

    # O último valor de cada aluno é o gabarito (Dropped_Out real)
    gabarito = [aluno[-1] for aluno in lista_novos_alunos]

    colunas_numericas = [
        'Age', 'Travel_Time', 'Study_Time', 'Number_of_Failures',
        'Free_Time', 'Going_Out', 'Weekend_Alcohol_Consumption',
        'Weekday_Alcohol_Consumption', 'Health_Status',
        'Number_of_Absences', 'Grade_1'
    ]

    # Garante que os dados sejam númericos (e não "18")
    for col in colunas_numericas:
        df_novos[col] = pd.to_numeric(df_novos[col], errors='coerce')

    previsoes = modelo_evasao_deploy.predict(df_novos)

    evasao = ['Não Evasão' if p == 0 else 'Evasão' for p in previsoes]
    rotulo = lambda v: 'Evasão' if v else 'Não Evasão'

    print("\n--- Resultados da Previsão ---")
    acertos = 0
    for i, resultado in enumerate(evasao):
        correto = bool(previsoes[i]) == bool(gabarito[i])
        acertos += correto
        marca = 'OK' if correto else 'X'
        print(f"Aluno {i+1:>2} -> Predição: {resultado:<11} | Esperado: {rotulo(gabarito[i]):<11} [{marca}]")

    total = len(evasao)
    print(f"\n--- Acertos: {acertos}/{total} ({100*acertos/total:.1f}%) ---")

# %%
# Executar a função de deploy com os novos dados
print("\n--- Iniciando Classificação de Novos Alunos ---\n")
prever_evasao(novos_alunos)
# Out:
# --- Iniciando Classificação de Novos Alunos ---
#
#
# --- Resultados da Previsão ---
# Aluno  1 -> Predição: Não Evasão  | Esperado: Não Evasão  [OK]
# Aluno  2 -> Predição: Evasão      | Esperado: Evasão      [OK]
# Aluno  3 -> Predição: Não Evasão  | Esperado: Não Evasão  [OK]
# Aluno  4 -> Predição: Não Evasão  | Esperado: Não Evasão  [OK]
# Aluno  5 -> Predição: Não Evasão  | Esperado: Não Evasão  [OK]
# Aluno  6 -> Predição: Não Evasão  | Esperado: Não Evasão  [OK]
# Aluno  7 -> Predição: Evasão      | Esperado: Evasão      [OK]
# Aluno  8 -> Predição: Não Evasão  | Esperado: Não Evasão  [OK]
# Aluno  9 -> Predição: Não Evasão  | Esperado: Não Evasão  [OK]
# Aluno 10 -> Predição: Não Evasão  | Esperado: Não Evasão  [OK]
# Aluno 11 -> Predição: Não Evasão  | Esperado: Não Evasão  [OK]
# Aluno 12 -> Predição: Não Evasão  | Esperado: Não Evasão  [OK]
# Aluno 13 -> Predição: Não Evasão  | Esperado: Não Evasão  [OK]
# Aluno 14 -> Predição: Evasão      | Esperado: Evasão      [OK]
# ...
